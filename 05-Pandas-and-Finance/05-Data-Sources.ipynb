# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright by Pierian Data Inc.</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# ### IMPORTANT NOTE: Your internet service provider or network admin or firewall may block you from directly reading information from outside sources. Please keep this in mind if you get errors. Also note, APIs change often, make sure to do your best independent research to explore current best options, as the code seen here may change.

# %% [markdown]
# ## Data Sources
# - Finanace
#     - Yahoo Finance
#     - Google Finance
#     - Finviz (a lot of info in a table for different data. See also Screener tab)
#     - Koyfin
#     - darqbe
#     - Valueline (analycal research)
#     - Bloomberg (is expensive)
#     - Ziggma
# - Regulatory sources
#     - finra
#     - EDGAR (US deparment)
#     - FRED

# %% [markdown]
# ## Pandas DataReader
#
# Make sure to check the latest examples and notification of API changes here:
# https://pandas-datareader.readthedocs.io/en/latest/remote_data.html#remote-data-wb

# %% [markdown]
# #### General Stock Data from Yahoo (not official API)

# %%
import pandas_datareader.data as web
import datetime

# %%
aapl_data = web.DataReader('AAPL', 'yahoo', start='2000-01-01', end='2021-01-01')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 aapl_data = web.DataReader('AAPL', 'yahoo', start='2000-01-01', end='2021-01-01')
#
# File E:\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File E:\AppData\Local\anaconda3\lib\site-packages\pandas_datareader\data.py:370, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
# --> 370     return YahooDailyReader(
#     371         symbols=name,
#     372         start=start,
#     373         end=end,
#     374         adjust_price=False,
# ...

# %%
aapl_df

# %% [markdown]
# # FRED
#
# https://fred.stlouisfed.org/
#
# 10-Year Breakeven Inflation Rate (T10YIE)
#
# https://fred.stlouisfed.org/series/T10YIE

# %%
ty_inflation_df = web.DataReader('T10YIE', 'fred', start='2000-01-01', end='2023-01-01')

# %%
ty_inflation_df.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# ### Yahoo Finance yfinance (unofficial API)

# %%
import yfinance as yf

# %%
apple= yf.download("AAPL",start='2020-01-01',end='2023-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
apple.Open.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### General Information

# %%
apple_ticker = yf.Ticker('AAPL')

# %%
apple_ticker.get_balance_sheet()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 apple_ticker.get_balance_sheet()
#
# File E:\AppData\Local\anaconda3\lib\site-packages\yfinance\base.py:1621, in TickerBase.get_balance_sheet(self, proxy, as_dict, pretty, freq, legacy)
#    1619     data = self._fundamentals.financials.get_balance_sheet_scrape(freq=freq, proxy=proxy)
#    1620 else:
# -> 1621     data = self._fundamentals.financials.get_balance_sheet_time_series(freq=freq, proxy=proxy)
#    1623 if pretty:
#    1624     data = data.copy()
#
# File E:\AppData\Local\anaconda3\lib\site-packages\yfinance\scrapers\fundamentals.py:119, in Financials.get_balance_sheet_time_series(self, freq, proxy)
#     117 res = self._balance_sheet_time_series
#     118 if freq not in res:
# --> 119     res[freq] = self._fetch_time_series("balance-sheet", freq, proxy=None)
# ...

# %%
apple_ticker.financials
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 apple_ticker.financials
#
# File E:\AppData\Local\anaconda3\lib\site-packages\yfinance\ticker.py:174, in Ticker.financials(self)
#     172 @property
#     173 def financials(self) -> _pd.DataFrame:
# --> 174     return self.income_stmt
#
# File E:\AppData\Local\anaconda3\lib\site-packages\yfinance\ticker.py:158, in Ticker.income_stmt(self)
#     156 @property
#     157 def income_stmt(self) -> _pd.DataFrame:
# --> 158     return self.get_income_stmt(pretty=True)
#
# File E:\AppData\Local\anaconda3\lib\site-packages\yfinance\base.py:1582, in TickerBase.get_income_stmt(self, proxy, as_dict, pretty, freq, legacy)
#    1580     data = self._fundamentals.financials.get_income_scrape(freq=freq, proxy=proxy)
#    1581 else:
# ...

# %%
apple_ticker.actions

# %%
apple_ticker.dividends
