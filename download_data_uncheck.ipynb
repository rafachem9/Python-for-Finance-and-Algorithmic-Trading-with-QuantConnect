# %%
import yfinance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web
from datetime import datetime, date
import yfinance as yf

# %matplotlib inline

# %%
import yfinance as yf
api_key= 'ZQQPPSYZLH811CS9'
spy_df = web.DataReader("AAPL", "av-daily", start=datetime(2025, 1, 1), end=datetime(2025, 7, 1), api_key=api_key)
spy_df.tail()
# Out:
#                open      high       low   close    volume
# 2025-06-25  201.450  203.6700  200.6201  201.56  39525730
# 2025-06-26  201.430  202.6400  199.4600  201.00  50799121
# 2025-06-27  201.890  203.2200  200.0000  201.08  73188571
# 2025-06-30  202.010  207.3900  199.2607  205.17  91912816
# 2025-07-01  206.665  210.1865  206.1401  207.82  78788867

# %%
company = 'AAPL'

# Define a start date and End Date
start = datetime(2024,1,1)
end =  datetime(2025,1,1)
yf.enable_debug_mode()
# Read Stock Price Data 
data = yf.download(company, start , end)

data.tail(10)
# Out:
# DEBUG    Entering download()
# DEBUG     Disabling multithreading because DEBUG logging enabled
# DEBUG     Entering history()
# DEBUG      Entering _fetch_ticker_tz()
# ERROR       Failed to get ticker 'AAPL' reason: Expecting value: line 1 column 1 (char 0)
# DEBUG      Exiting _fetch_ticker_tz()
# ERROR
#           1 Failed download:
# ERROR     ['AAPL']: Exception('%ticker%: No timezone found, symbol may be delisted')
# DEBUG     ['AAPL']: Traceback (most recent call last):
#             File "/home/rafachem9/Documents/venv-next/Python-for-Finance-and-Algorithmic-Trading-with-QuantConnect/lib/python3.12/site-packages/yfinance/multi.py", line 279, in _download_one
#               data = Ticker(ticker).history(
#                      ^^^^^^^^^^^^^^^^^^^^^^^
#             File "/home/rafachem9/Documents/venv-next/Python-for-Finance-and-Algorithmic-Trading-with-QuantConnect/lib/python3.12/site-packages/yfinance/utils.py", line 108, in wrapper
#               result = func(*args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^
#             File "/home/rafachem9/Documents/venv-next/Python-for-Finance-and-Algorithmic-Trading-with-QuantConnect/lib/python3.12/site-packages/yfinance/base.py", line 155, in history
#               raise Exception(f'{self.ticker}: {err_msg}')
#           Exception: %ticker%: No timezone found, symbol may be delisted
#
# DEBUG    Exiting download()
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
import yfinance as yf

# Define the ticker symbol
ticker_symbol = "AAPL"

# Create a Ticker object
ticker = yf.Ticker(ticker_symbol)

# Fetch historical market data
historical_data = ticker.history(period="1y")  # data for the last year
print("Historical Data:")
print(historical_data)
# Out:
# DEBUG    Entering history()
# DEBUG     Entering _fetch_ticker_tz()
# ERROR      Failed to get ticker 'AAPL' reason: Expecting value: line 1 column 1 (char 0)
# DEBUG     Exiting _fetch_ticker_tz()
# DEBUG     AAPL: Yahoo GET parameters: {'range': '1y', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# DEBUG     Entering get()
# DEBUG      url=https://query2.finance.yahoo.com/v8/finance/chart/AAPL
# DEBUG      params={'range': '1y', 'interval': '1d', 'includePrePost': False, 'events': 'div,splits,capitalGains'}
# DEBUG      Entering _get_cookie_and_crumb()
# DEBUG       cookie_mode = 'basic'
# DEBUG       Entering _get_cookie_and_crumb_basic()
# DEBUG        reusing cookie
# DEBUG        reusing crumb
# DEBUG       Exiting _get_cookie_and_crumb_basic()
# DEBUG      Exiting _get_cookie_and_crumb()
# DEBUG      response code=429
# DEBUG      toggling cookie strategy basic -> csrf
# DEBUG      Entering _get_cookie_and_crumb()
# DEBUG       cookie_mode = 'csrf'
# DEBUG       Entering _get_crumb_csrf()
# DEBUG        loaded persistent cookie
# DEBUG        Failed to find "csrfToken" in response
# DEBUG       Exiting _get_crumb_csrf()
# DEBUG       toggling cookie strategy csrf -> basic
# DEBUG       Entering _get_cookie_and_crumb_basic()
# DEBUG        loaded persistent cookie
# DEBUG        reusing cookie
# DEBUG        crumb = 'Edge: Too Many Requests'
# DEBUG       Exiting _get_cookie_and_crumb_basic()
# DEBUG      Exiting _get_cookie_and_crumb()
# DEBUG      response code=429
# DEBUG     Exiting get()
# ERROR     AAPL: No price data found, symbol may be delisted (period=1y)
# DEBUG    Exiting history()
# Historical Data:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []
